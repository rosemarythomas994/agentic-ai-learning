# %%
# Import necessary packages
from pydantic import BaseModel, ValidationError, Field, EmailStr
from typing import List, Literal, Optional
import json
from datetime import date
from dotenv import load_dotenv
import openai

# %%
# Load environment variables for API access
load_dotenv()
# Initialize OpenAI client for API calls
client = openai.OpenAI()

# %%
# Define a function to call the LLM
def call_llm(prompt, model="gpt-4o"):
    response = client.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": prompt}]
    )
    return response.choices[0].message.content

# %%
pip install pdfplumber
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pdfplumber in /home/jovyan/.local/lib/python3.11/site-packages (0.11.7)
# Requirement already satisfied: pdfminer.six==20250506 in /home/jovyan/.local/lib/python3.11/site-packages (from pdfplumber) (20250506)
# Requirement already satisfied: Pillow>=9.1 in /usr/local/lib/python3.11/site-packages (from pdfplumber) (11.3.0)
# Requirement already satisfied: pypdfium2>=4.18.0 in /home/jovyan/.local/lib/python3.11/site-packages (from pdfplumber) (4.30.0)
# Requirement already satisfied: charset-normalizer>=2.0.0 in /usr/local/lib/python3.11/site-packages (from pdfminer.six==20250506->pdfplumber) (3.4.2)
# Requirement already satisfied: cryptography>=36.0.0 in /home/jovyan/.local/lib/python3.11/site-packages (from pdfminer.six==20250506->pdfplumber) (45.0.7)
# Requirement already satisfied: cffi>=1.14 in /usr/local/lib/python3.11/site-packages (from cryptography>=36.0.0->pdfminer.six==20250506->pdfplumber) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/site-packages (from cffi>=1.14->cryptography>=36.0.0->pdfminer.six==20250506->pdfplumber) (2.22)
#
# [notice] A new release of pip is available: 25.1 -> 25.2
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pdfplumber

def extract_pdf_text_to_variable(pdf_path):
    text_data = ""
    with pdfplumber.open(pdf_path) as pdf:
        for page in pdf.pages:
            page_text = page.extract_text()
            if page_text:
                text_data += page_text + "\n"
    return text_data

# Usage example
pdf_file = "AFP0080 SNAP-R Print (Works as Expected).pdf"   # Replace with your PDF file path
md_text = extract_pdf_text_to_variable(pdf_file)

print(md_text)  # Now pdf_text variable contains all the PDF text
# Out:
# An official website of the United States government Here's how you know
# Bureau of Industry and Security
# U.S. Department of Commerce
# Export License Application
# Status ACCEPTED
# Contact Information
# Reference Number
# AFP0080
# 1. Contact Person (First Name, Last Name)
# Zeljko Tolo
# 2. Telephone Number 3. Fax Number
# 216-317-9273 -
# Email
# ztolo@aerofp.com
# 4. Creation Date
# 06/19/2025
# 5. Type of Application
# Export License Application
# Document Checklist
# 6. Documents submitted with application 7. Documents on file with applicant
# ✔ Export Items (BIS-748P-A) BIS-711
# ✔ End Users (BIS-748P-B) Letter of Assurance
# BIS-711 Import/End-User Certificate
# ✔ Import/End-User Certificate Nuclear Certification
# ✔ Technical Specification
# Other
# ✔ Letter of Explanation -
# Foreign Availability
# Other
# -
# Tell us what to improve
# License Information
# 9. Special Purpose
# Technology
# 10. Resubmission ACN 11. Replacement License Number
# - -
# 13. Import Certificate Country Import Certificate Number
# - -
# Applicant Information
# 14. CIN (Applicant ID) Applicant
# A703543 Aero Fluid Products
# Address 1 Address 2
# 313 Gillett St. -
# City Country
# Painesville UNITED STATES
# State/Province Postal Code
# Ohio 44077
# EIN
# 26-0379798
# Other Party Information
# 15. Other Party ID Other Party
# - -
# Address 1 Address 2
# - -
# City Country
# - -
# State/Province Postal Code
# - -
# Telephone or Fax
# -
# a) If you are a First Party submitter and will be the Principal Party in Interest using this license, note
# that, in the electronic environment, this block does not function to send a license to any other
# interested party, and no other interested party will appear on the license.
# If you wish another party to be authorized to discuss this license, please enter the information in
# Block 24 (Additional Information) and name specific individuals.
# b) If you need to add any party to be authorized under the license, but for whom there is no available
# field (such as a second Intermediate Consignee), list that party in Block 19 (End User Information),
# even if they are not an End User, and explain their role in the transaction in Block 24 (Additional
# Information), or in an attached Letter of Explanation.
# Purchaser Information
# 16. Purchaser
# EMBRAER S.A.
# Address 1 Address 2
# Rodovia Presidente Dutra, Km 134, Eugenio de (And all Brazilian Locations)
# Melo
# City Country
# Sao Jose dos Campos, SP BRAZIL
# State/Province Postal Code
# - -
# Telephone or Fax
# -
# Intermediate Consignee Information
# 17. Intermediate Consignee
# DSV AIR & SEA
# Address 1 Address 2
# Av. Jornalista Roberto Marinho, 85 (And all Brazilian Locations)
# City Country
# Sao Paulo-SP BRAZIL
# State/Province Postal Code
# - 04575-000
# Telephone or Fax
# -
# Ultimate Consignee Information
# 18. Ultimate Consignee
# EMBRAER S.A.
# Address 1 Address 2
# Rodovia Presidente Dutra, Km 134, Eugenio de (And all Brazilian Locations)
# Melo
# City Country
# Sao Jose dos Campos, SP BRAZIL
# State/Province Postal Code
# - -
# Telephone or Fax
# -
# End User Information
# 19.
# Address Address Postal Telephone
# End City Country
# Line 1 Line 2 Code or Fax
# User
# Estrada
# Municipal (And all Gaviao
# EMBRA
# Euclides Brazilian Peixot BRAZIL
# ER S.A.
# Martins, Locations) o, SP
# 2170
# Depart Camp (And all Quezo PHILIPPINES 1110
# ment of General Philippines n City
# Nation Emilio Locations)
# al Aguinaldo,
# Defens Natividad
# e/Arme Ave,
# d
# Forces
# 19.
# Address Address Postal Telephone
# End City Country
# Line 1 Line 2 Code or Fax
# User
# of The
# Philippi
# nes
# Base Aerea
# General
# Ecuado Eloy Alfaro, (And all
# rian Air Ala de Ecuador Manta ECUADOR
# Force Combate # Locations)
# 23 Via a
# Jaramijo
# Comando
# Logistico
# Chilean de la FACH. (And all Los
# Air Avenida Chilean Cerrilo CHILE
# Force Pedro Locations) s
# Aguirre,
# S/N
# ENAER
# –
# EMPRE
# Gran
# SA
# Avenida
# NACIO (And all
# Jose Santia
# NAL Chilean CHILE
# Miguel go
# DE Locations)
# Carrera,
# AERON
# 11087
# AUTIC
# A DE
# CHILE
# Directoria
# de
# Domini
# Proyectos
# can (And all Santo
# Y
# Republi Dominican Domin DOMINICAN
# Programas,
# c Air Republic go REPUBLIC
# Base Aerea
# Force - Locations) Este
# De San
# FAD
# Isidro, San
# Isidro
# 19.
# Address Address Postal Telephone
# End City Country
# Line 1 Line 2 Code or Fax
# User
# Colomb
# ian Air Ministerio Avenida El
# Force de Defensa Dorado,
# (And all Naciona CAN Bogota
# COLOMBIA
# Columb Grupo Carrera 52 DC
# ian Contratacio - Oficina
# Locatio n Estatal 203
# ns)
# Brazilia
# Ministerio
# n Air Esplanada
# da Defesa,
# Force dos
# Comando
# (And all Ministerios, Brasíli 70045-
# da BRAZIL
# Brazilia Bloco M, a DF 900
# Aeronautic
# n Anexo A, 2
# a -
# Locatio Andar
# COMAER
# ns)
# Ministr
# y Of
# Defens Jalan
# e Of Medan (And all
# Jakarta
# The Merdeka Indonesian INDONESIA 10110
# Pusat
# Republi Barat, No. Locations)
# c Of 13 – 14
# Indone
# sia
# FANA -
# Forca
# Aerea Operator
# Angola and Rua
# na Foreign Augusto
# (Angol End-user* Tadeu de Bairro
# a Air Quartel Bastos – ex- Maiang ANGOLA
# Force) General da 05 de a
# (And all Força Outubro no
# Angolia Aerea 66/68
# n Nacional
# Locatio
# ns)
# 19.
# Address Address Postal Telephone
# End City Country
# Line 1 Line 2 Code or Fax
# User
# Simpor
# tex
# Comer
# cializac
# ao De
# Equip e
# (And all
# Meios Rua Rainha Luanda
# Angolan ANGOLA 2952
# Materia Ginga 24 , C.P.
# Locations)
# is
# Import
# &
# Export
# Angola
# n Gov
# GOVER
# NMEN
# T OF
# Zone
# THE
# Aeroport (And all
# ISLAMI Nouak
# Internation Mauritania MAURITANIA BP 208
# C chott
# al de Locations)
# REPUB
# Nouakchott
# LIC OF
# MAURI
# TANIA
# Estado-
# Portug Maior da
# uese Força (And all
# Amado N 1 2614-
# Air Aerea Av. Portuguese PORTUGAL
# ra 506
# Force da Força Locations)
# (FAP) Aerea
# Portuguesa
# The
# Ministr
# (And all
# y of
# Galkynysh Turkmenist Ashga
# Defens TURKMENISTAN 744000
# street, 4 an bat
# e of
# Locations)
# Turkme
# nistan
# 19.
# Address Address Postal Telephone
# End City Country
# Line 1 Line 2 Code or Fax
# User
# Avda.
# Ciudad
# Fuerza General
# (And all de
# Aerea Jose
# Paraguay Luque PARAGUAY
# Paragu Elizardo
# Locations) Republ
# aya Aquino,
# ica
# 1792
# Fuerza Av. Pedro
# (And all
# Aerea de Montev
# Uruguay URUGUAY
# Urugua Mendoza, ideo
# Locations)
# ya 5553
# DSV 19-23
# (And all
# AIR & Chemin des Genne
# French FRANCE 92230
# SEA Petits villiers
# Locations)
# SAS Marais
# DSV 3 rue du
# (And all
# AIR & Remblai – Trembl
# French FRANCE 93290
# SEA Zone cargo ay
# Locations)
# SAS 4
# Unit 1,
# DSV
# Polar Park,
# AIR & (And all UK Heathr UNITED
# Bath Road UB7 0EX
# SEA Locations) ow KINGDOM
# West
# LTD
# Drayton
# DSV
# (And all
# AIR & Gruener Hambu GERMANY,
# German 20097
# SEA Deich 1 rg FEDERAL REP
# Locations)
# GMBH
# YEHUD AMIT (And all Tel ISRAEL 70100
# IT Building, Israeli Aviv
# HAZAN Airport Locations)
# BERGE City, Ben
# L - COO Gurion
# EXPOR Airport PO
# T AIR Box 77
# AND
# SEA
# The A
# 19.
# Address Address Postal Telephone
# End City Country
# Line 1 Line 2 Code or Fax
# User
# M IT
# GROUP
# DSV
# AIR & 44 (And all
# SEA Hama'ayan Israeli Modi'in ISRAEL 7173000
# ISRAEL Street Locations)
# LTD.
# Limito
# Via Dante (And all
# DSV di
# Alighieri,13 Italian ITALY 20096
# S.P.A. Piotell
# 4 Locations)
# o
# Industriezo
# DSV Puurs-
# ne Puurs (And all
# AIR & Sint-
# 533 Belgium BELGIUM BE-2870
# SEA Amand
# Schoonma Locations)
# NV s
# nsveld 40
# Zona
# DSV
# Industrial
# AIR (And all
# do Cabo
# AND Portuguese Lisboa PORTUGAL 2600-695
# Castanheir
# SEA Locations)
# a do
# LDA
# Ribatejo
# DSV Vilar
# Rua Campo (And all
# TRANS do 4485-
# do Martelo, Portugal PORTUGAL
# ITARIO Pinheir 000
# 319 Locations)
# S, LDA o
# DSV
# (And all
# AIR & Driver Road Brampt
# Canadian CANADA L6T 5V2
# SEA unit 4 on
# Locations)
# Inc
# SERVI Avenida
# MEX Moema, (And all Sao
# 04077-
# LOGIST 877 – Brazilian Paulo- BRAZIL
# 023
# ICA Indianopoli Locations) SP
# LTDA. s
# Schenk Rua (And all Sao BRAZIL 04575-
# er do Geraldo Brazilian Paulo- 093
# 19.
# Address Address Postal Telephone
# End City Country
# Line 1 Line 2 Code or Fax
# User
# Brasil Flausino Locations) SP
# Transp Gomes, 78
# ortes - 12º andar,
# Interna Brooklin
# cionais
# LTDA.
# Transp
# Rua
# ortador
# Marginal (And all
# a Botuca 18606-
# 200, nº Brazilian BRAZIL
# Aquari tu – SP 550
# 600-Vila Locations)
# un
# Real
# LTDA.
# DHL
# Avenida
# Expres (And all Sao
# Santa
# s Brazilian Paulo- BRAZIL
# Marina,
# (Brazil) Locations) SP
# 1660-Lapa
# LTDA.
# 37 route
# SCHEN (And all Genne
# principale
# KER French villiers FRANCE F-92 637
# du port CE
# S.A. Locations) Cedex
# 214
# DB
# SCHEN
# Head
# KER
# Office -
# KOREA Gonghangd
# Airport KOREA,
# LTD. ong-ro 296 Incheo
# Logistics REPUBLIC OF 22379
# (And all beon-gil, n
# Park G3 (SOUTH KOREA)
# South Junggu
# block, 97-
# Korean
# 49
# Locatio
# ns)
# DHL Sort (And all Villene FRANCE
# Expres centre, 9 French uve La
# s Sort Rue du Cdt Locations) Garenn
# Center d Estienne e
# Paris d Orves
# ZAC du
# parc des
# 19.
# Address Address Postal Telephone
# End City Country
# Line 1 Line 2 Code or Fax
# User
# Chanterein
# es
# UPS do
# Brasil
# Rua Dom
# Remes (And all Sao
# Aguirre, nº
# sas Brazilian Paulo- BRAZIL 04671245
# 554-Jardim
# Expres Locations) SP
# Marajoara
# sas
# LTDA
# FEDEX Avenida
# Expres das Naçoes (And all Sao
# s Unidas, Brazilian Paulo- BRAZIL
# Corpor nº17891-1º Locations) SP
# ation andar
# Avenida
# Phenix Educador
# Transp Paulo (And all Sao
# orte de Freire, 111- Brazilian Paulo- BRAZIL 02187-110
# Cargas Parque Locations) SP
# LTDA. Novo
# Mundo
# Alameda
# Master
# dos
# Freight
# Jurupis,
# Transp (And all Sao
# 452-Conj. 04088-
# ortes Brazilian Paulo- BRAZIL
# 71 - Bloco 901
# Interna Locations) SP
# A-
# cionaiS
# Indianopoli
# LTDA.
# s
# PGL
# Av. Dr. Lino
# Prime
# de Mores
# Agenci (And all Sao
# Leme, 04360-
# amento Brazilian Paulo- BRAZIL
# 1138-1 000
# de Locations) SP
# Andar-Vila
# Carga
# Paulista
# LTDA.
# M & K Rua (And all Sao BRAZIL 09634-
# Assess Jacquey, Brazilian Bernar 000
# 19.
# Address Address Postal Telephone
# End City Country
# Line 1 Line 2 Code or Fax
# User
# oria, 163-3 Locations) do do
# Export ANDAR- Campo
# adora, Vila Helena -SP
# Import
# adora
# LTDA.
# Av. Jose de
# Expedit
# Souza
# ors Campi
# Campos,
# Interna (And all nas,
# 575 13092-
# tional Brazilian Bairro BRAZIL
# Edificio 106
# do Locations) Cambu
# 575 Norte
# Brasil i
# Sul-6º
# LTDA.
# andar
# Vila
# RUA
# (And all Olimpi
# Enterpr Alvorada, 04550-
# Brazilian a-Sao BRAZIL
# ise 1289-3º 004
# Locations) Paulo-
# andar
# SP
# KUEHN Avenida
# (And all
# E + Calle 26,
# Columbian Bogota COLOMBIA
# NAGEL 106-39,
# Locations)
# S.A.S Piso 4
# SUNRI Calle 46 A
# (And all
# SE No 82-54
# Columbian Bogota COLOMBIA
# CARGO Porteria 2,
# Locations)
# S.A. Interior 8
# Av.
# KUEHN
# Providencia (And all
# E + Santia
# 2331 Of. Chilean CHILE
# NAGEL go
# 301 And Locations)
# LTDA
# 302
# DB
# SCHEN
# General del (And all
# KER Santia
# Canto 421, Chilean CHILE 7500588
# LOGIST go
# Piso 3 Locations)
# ICS IN
# CHILE
# 19.
# Address Address Postal Telephone
# End City Country
# Line 1 Line 2 Code or Fax
# User
# Av. Irlanda
# E10-16 Y
# KUEHN Republica
# (And all
# E + Del
# Ecuador Quito ECUADOR
# NAGEL Salvador
# Locations)
# S.A. Edif. Torre
# Siglo XXI
# Piso No. 7
# SERVIC
# IOS
# AEREO Parque
# S Y Empresaria
# MARITI l Colon
# (And all
# MOS Edificio Guaya
# Ecuador ECUADOR
# INTER Corporativo quil
# Locations)
# NACIO #2 Piso 2
# NALES Oficina #
# SA 204
# (SAMIS
# A)
# CARIB
# ETRAN
# S,
# S.A.|BA Calle Jose (And all
# Santo
# SC Gabriel Dominican DOMINICAN Postal
# Domin
# CERTIF Garcia No. Republic REPUBLIC 1713
# go
# IED 8 Apartado Locations)
# DOMS
# DQ000
# 03
# Av. 27 de
# Febrero Ens.
# (And all
# DB Esq. Naco,
# Dominican DOMINICAN
# SCHEN Tiradentes, Santo
# Republic REPUBLIC
# KER Plaza Domin
# Locations)
# Merengue go
# Local 102
# First Previous 1 of 2 Next Last
# Specific End Use
# 21. Specific End Use
# 5344-00-1 Valve is used as a component of the anti-icing air system. Valve is used to control
# the flow of engine bleed air within the anti-icing system.
# Export Item Information
# 22. Export Item #1
# (a) ECCN (b) APP (c) Product/Model Number (d) CCATS Number
# 9A610 - 5344-00-1 -
# (e) Quantity (f) Units (g) Unit Price (h) Total Price (i) Manufacturer
# 1 each $5995 $5995 Aero Fluid Products
# (j) Technical Description
# 5344-00-1 Normally closed 1.5” shutoff valve that is solenoid operated. There is also a
# switch to indicate valve position.
# 22. Export Item #2
# (a) ECCN (b) APP (c) Product/Model Number (d) CCATS Number
# 9E610 - Technology -
# (e) Quantity (f) Units (g) Unit Price (h) Total Price (i) Manufacturer
# 1 Lot $1 $1 Aero Fluid Produts
# (j) Technical Description
# The 9E610 Technology to be provided to Embraer is required to support the design,
# installation, maintenance, and repair of the 5344-00-1. The Information may be in any
# tangible or intangible form, such as written or oral communications, drawings,
# photographs, engineering designs and specifications, computer-aided design files,
# manuals or documentation, electronic media or information revealed through visual
# inspection.
# Total Application Dollar Value
# 23. Total Application Dollar Value
# $5,996.00
# Additional Information
# 24. Additional Information
# The remainder of the Intermediate Consignees are in Block 19.
# Documents attached to application
# Title Author Document Type View
# Embraer End User Statement Import/End-User
# Embraer S.A.
# 905660040 Copy Certificate
# AFP0080 Letter of Explanation Zeljko Tolo Letter of Explanation
# 5344-00-1 Acceptance Test Aero Fluid
# Tech. Specs.
# Report Products
# Aero Fluid
# 5344-00-1 Drawing Tech. Specs.
# Products
# First Previous 1 of 1 Next Last
# Signer Information
# Name
# Z.TOLO
# Title
# Dir of Comp
# Email
# ztolo@aerofp.com

# %%
prompt = f"""
You are a document parser. Your task is to convert the provided PDF text and form data
into structured JSON.

Rules:

1. Include all fields in the output JSON, even if their value is empty or null.
Understand the file structure.
2. Input may contain checkbox fields, understand how it is represented.
For checkboxes or radio buttons:
   -Include only the items that are selected (marked with '✔' or similar).
   - If no items in a checkbox/radio group are selected, set the field to null.
   - Do NOT output boolean true/false for unselected items.
   - Extract only the items that are marked as selected, indicated by a leading '✔' or similar mark.
    - Ignore items without any selection mark.
    - If no items are selected in a checklist, set it to null.
    - Include only the items that are marked as selected, indicated by a leading '✔', or 'n' or similar mark.
  - Do NOT output boolean true/false flags for items.
  - If no items are selected in a checklist, set that checklist field to null.
  - if checkbox is under different column in table, keep it under that column name. You have follow the structure.

3. Split full names into 'FirstName' and 'LastName' if possible.
4. Group logically related fields together.
5. Output valid JSON only. No explanation, no extra text.
6.Extract data if it is split into two coloumns and/or numbered columns data

Here are the filled form fields (checkboxes, radios, etc.):

{md_text}

Here is the extracted text from the PDF:

{md_text}
"""
prompt_ = prompt.format(md_text=md_text)

# %%
# Get response from LLM
# print(prompt_)
import re
from pprint import pprint
response_content = call_llm(prompt_)
pattern = r'<text>(.*?)</text>'
match = re.search(pattern, response_content, re.DOTALL)
if match:
    resp = json.loads(match.group(1))
    pprint(resp)
    print(resp.keys())
else:
    print(response_content)
# Out:
# ```json
# {
#   "ExportLicenseApplication": {
#     "Status": "ACCEPTED",
#     "ContactInformation": {
#       "ReferenceNumber": "AFP0080",
#       "ContactPerson": {
#         "FirstName": "Zeljko",
#         "LastName": "Tolo"
#       },
#       "TelephoneNumber": "216-317-9273",
#       "FaxNumber": null,
#       "Email": "ztolo@aerofp.com",
#       "CreationDate": "06/19/2025",
#       "TypeOfApplication": "Export License Application"
#     },
#     "DocumentChecklist": {
#       "DocumentsSubmittedWithApplication": [
#         "Export Items (BIS-748P-A)",
#         "End Users (BIS-748P-B)",
#         "Import/End-User Certificate",
#         "Technical Specification",
#         "Letter of Explanation"
#       ],
#       "DocumentsOnFileWithApplicant": null
#     },
#     "LicenseInformation": {
#       "SpecialPurpose": "Technology",
#       "ResubmissionACN": null,
#       "ReplacementLicenseNumber": null,
#       "ImportCertificate": {
#         "Country": null,
#         "Number": null
#       }
#     },
#     "ApplicantInformation": {
#       "CIN": "A703543",
#       "Applicant": "Aero Fluid Products",
#       "Address": {
#         "Address1": "313 Gillett St.",
#         "Address2": null,
#         "City": "Painesville",
#         "Country": "UNITED STATES",
#         "StateProvince": "Ohio",
#         "PostalCode": "44077"
#       },
#       "EIN": "26-0379798"
#     },
#     "OtherPartyInformation": {
#       "OtherPartyID": null,
#       "OtherParty": null,
#       "Address": {
#         "Address1": null,
#         "Address2": null,
#         "City": null,
#         "Country": null,
#         "StateProvince": null,
#         "PostalCode": null
#       },
#       "TelephoneOrFax": null
#     },
#     "PurchaserInformation": {
#       "Purchaser": "EMBRAER S.A.",
#       "Address": {
#         "Address1": "Rodovia Presidente Dutra, Km 134, Eugenio de Melo",
#         "Address2": "(And all Brazilian Locations)",
#         "City": "Sao Jose dos Campos, SP",
#         "Country": "BRAZIL",
#         "StateProvince": null,
#         "PostalCode": null
#       },
#       "TelephoneOrFax": null
#     },
#     "IntermediateConsigneeInformation": {
#       "IntermediateConsignee": "DSV AIR & SEA",
#       "Address": {
#         "Address1": "Av. Jornalista Roberto Marinho, 85",
#         "Address2": "(And all Brazilian Locations)",
#         "City": "Sao Paulo-SP",
#         "Country": "BRAZIL",
#         "StateProvince": null,
#         "PostalCode": "04575-000"
#       },
#       "TelephoneOrFax": null
#     },
#     "UltimateConsigneeInformation": {
#       "UltimateConsignee": "EMBRAER S.A.",
#       "Address": {
#         "Address1": "Rodovia Presidente Dutra, Km 134, Eugenio de Melo",
#         "Address2": "(And all Brazilian Locations)",
#         "City": "Sao Jose dos Campos, SP",
#         "Country": "BRAZIL",
#         "StateProvince": null,
#         "PostalCode": null
#       },
#       "TelephoneOrFax": null
#     },
#     "EndUserInformation": [
#       {
#         "EndUser": "EMBRAER S.A.",
#         "AddressLine1": "Estrada Municipal Euclides Martins, 2170",
#         "AddressLine2": "(And all Brazilian Locations)",
#         "City": "Gaviao Peixoto",
#         "Country": "BRAZIL",
#         "PostalCode": null,
#         "TelephoneOrFax": null
#       },
#       {
#         "EndUser": "Department of National Defense/Armed Forces of The Philippines",
#         "AddressLine1": "Camp General Emilio Aguinaldo, Natividad",
#         "AddressLine2": "Ave",
#         "City": "Quezon City",
#         "Country": "PHILIPPINES",
#         "PostalCode": "1110",
#         "TelephoneOrFax": null
#       },
#       {
#         "EndUser": "Ecuadorian Air Force",
#         "AddressLine1": "Base Aerea Eloy Alfaro, Ala de Combate #23 Via a Jaramijo",
#         "AddressLine2": "(And all Ecuador Locations)",
#         "City": "Manta",
#         "Country": "ECUADOR",
#         "PostalCode": null,
#         "TelephoneOrFax": null
#       },
#       {
#         "EndUser": "Chilean Air Force",
#         "AddressLine1": "Comando Logistico de la FACH. Avenida Pedro Aguirre, S/N",
#         "AddressLine2": "(And all Chilean Locations)",
#         "City": "Los Cerrilos",
#         "Country": "CHILE",
#         "PostalCode": null,
#         "TelephoneOrFax": null
#       },
#       {
#         "EndUser": "ENAER – EMPRESA NACIONAL DE AERONAUTICA DE CHILE",
#         "AddressLine1": "Gran Avenida Jose Miguel Carrera, 11087",
#         "AddressLine2": "(And all Chilean Locations)",
#         "City": "Santiago",
#         "Country": "CHILE",
#         "PostalCode": null,
#         "TelephoneOrFax": null
#       },
#       {
#         "EndUser": "Dominican Republic Air Force - FAD",
#         "AddressLine1": "Directoria de Proyectos Y Programas, Base Aerea De San Isidro",
#         "AddressLine2": "(And all Dominican Republic Locations)",
#         "City": "Santo Domingo Este",
#         "Country": "DOMINICAN REPUBLIC",
#         "PostalCode": null,
#         "TelephoneOrFax": null
#       },
#       {
#         "EndUser": "Colombian Air Force",
#         "AddressLine1": "Ministerio de Defensa Nacional Grupo Contratacion Estatal",
#         "AddressLine2": "(And all Columbian Locations)",
#         "City": "Bogota",
#         "Country": "COLOMBIA",
#         "PostalCode": null,
#         "TelephoneOrFax": null
#       },
#       {
#         "EndUser": "Brazilian Air Force",
#         "AddressLine1": "Ministerio da Defesa, Comando da Aeronautica",
#         "AddressLine2": "Esplanada dos Ministerios, Bloco M, Anexo A, 2 Andar",
#         "City": "Brasília",
#         "Country": "BRAZIL",
#         "PostalCode": "70045-900",
#         "TelephoneOrFax": null
#       },
#       {
#         "EndUser": "Ministry Of Defense Of The Republic Of Indonesia",
#         "AddressLine1": "Jalan Medan Merdeka Barat, No. 13 – 14",
#         "AddressLine2": "(And all Indonesian Locations)",
#         "City": "Jakarta Pusat",
#         "Country": "INDONESIA",
#         "PostalCode": "10110",
#         "TelephoneOrFax": null
#       },
#       {
#         "EndUser": "FANA - Forca Aerea na Foreign End-user*",
#         "AddressLine1": "Rua Augusto Tadeu de Bastos – ex-Quartel General da Força Aerea Nacional",
#         "AddressLine2": "(And all Angolian Locations)",
#         "City": "Bairro Maianga",
#         "Country": "ANGOLA",
#         "PostalCode": null,
#         "TelephoneOrFax": null
#       },
#       {
#         "EndUser": "Governement of The Islamic Republic Of Mauritania",
#         "AddressLine1": "Zone Aeroport Internation de Nouakchott",
#         "AddressLine2": "(And all Mauritania Locations)",
#         "City": "Nouakchott",
#         "Country": "MAURITANIA",
#         "PostalCode": "BP 208",
#         "TelephoneOrFax": null
#       },
#       {
#         "EndUser": "Estado-Portuguese Air Force (FAP)",
#         "AddressLine1": "Portug Amado N 1 Av. da Força Aerea Portuguesa",
#         "AddressLine2": "(And all Portuguese Locations)",
#         "City": "",
#         "Country": "PORTUGAL",
#         "PostalCode": "2614-506",
#         "TelephoneOrFax": null
#       },
#       {
#         "EndUser": "The Ministry of Defense of Turkmenistan",
#         "AddressLine1": "Galkynysh street, 4",
#         "AddressLine2": "(And all Turkmenistan Locations)",
#         "City": "Ashgabat",
#         "Country": "TURKMENISTAN",
#         "PostalCode": "744000",
#         "TelephoneOrFax": null
#       },
#       {
#         "EndUser": "Fuerza Aerea de Paraguay",
#         "AddressLine1": "Avda. Ciudad General Jose Elizardo Aquino, 1792",
#         "AddressLine2": "(And all Paraguay Republic Locations)",
#         "City": "Luque",
#         "Country": "PARAGUAY",
#         "PostalCode": null,
#         "TelephoneOrFax": null
#       },
#       {
#         "EndUser": "Fuerza Aerea de Uruguay",
#         "AddressLine1": "Av. Pedro de Mendoza, 5553",
#         "AddressLine2": "(And all Uruguay Locations)",
#         "City": "Montevideo",
#         "Country": "URUGUAY",
#         "PostalCode": "5553",
#         "TelephoneOrFax": null
#       },
#       {
#         "EndUser": "DSV AIR & SEA SAS",
#         "AddressLine1": "19-23 Chemin des Petits Marais",
#         "AddressLine2": "(And all French Locations)",
#         "City": "Gennevilliers",
#         "Country": "FRANCE",
#         "PostalCode": "92230",
#         "TelephoneOrFax": null
#       },
#       {
#         "EndUser": "DSV AIR & SEA SAS",
#         "AddressLine1": "3 rue du Remblai – Zone cargo 4",
#         "AddressLine2": "(And all French Locations)",
#         "City": "Tremblay",
#         "Country": "FRANCE",
#         "PostalCode": "93290",
#         "TelephoneOrFax": null
#       },
#       {
#         "EndUser": "DSV AIR & SEA LTD",
#         "AddressLine1": "Unit 1, Polar Park, Bath Road",
#         "AddressLine2": "(And all UK Locations)",
#         "City": "Heathrow",
#         "Country": "UNITED KINGDOM",
#         "PostalCode": "UB7 0EX",
#         "TelephoneOrFax": null
#       },
#       {
#         "EndUser": "DSV AIR & SEA GMBH",
#         "AddressLine1": "Gruener Deich 1",
#         "AddressLine2": "(And all German Locations)",
#         "City": "Hamburg",
#         "Country": "GERMANY, FEDERAL REP",
#         "PostalCode": "20097",
#         "TelephoneOrFax": null
#       },
#       {
#         "EndUser": "YEHUD AMIT IT HAZAN BERGER L - COO EXPORT AIR AND SEA",
#         "AddressLine1": "AMIT Building, Airport City, Ben Gurion Airport",
#         "AddressLine2": "(And all Israeli Locations)",
#         "City": "Tel Aviv",
#         "Country": "ISRAEL",
#         "PostalCode": "70100",
#         "TelephoneOrFax": null
#       },
#       {
#         "EndUser": "The A M IT GROUP",
#         "AddressLine1": "44 Hama'ayan Street",
#         "AddressLine2": "(And all Israeli Locations)",
#         "City": "Modi'in",
#         "Country": "ISRAEL",
#         "PostalCode": "7173000",
#         "TelephoneOrFax": null
#       },
#       {
#         "EndUser": "DSV SPA",
#         "AddressLine1": "Via Dante Alighieri,13 4",
#         "AddressLine2": "(And all Italian Locations)",
#         "City": "Pioltello",
#         "Country": "ITALY",
#         "PostalCode": "20096",
#         "TelephoneOrFax": null
#       },
#       {
#         "EndUser": "DSV AIR & SEA NV",
#         "AddressLine1": "Industriezone Puurs--Sint Amands Schoonmansveld 40",
#         "AddressLine2": "(And all Belgium Locations)",
#         "City": "Puurs",
#         "Country": "BELGIUM",
#         "PostalCode": "BE-2870",
#         "TelephoneOrFax": null
#       },
#       {
#         "EndUser": "DSV AIR AND SEA LDA",
#         "AddressLine1": "Zona Industrial do Cabo Castanheira do Ribatejo",
#         "AddressLine2": "(And all Portuguese Locations)",
#         "City": "Lisboa",
#         "Country": "PORTUGAL",
#         "PostalCode": "2600-695",
#         "TelephoneOrFax": null
#       },
#       {
#         "EndUser": "DSV TRANSITARIO S, LDA",
#         "AddressLine1": "Rua Campo do Martelo, 319",
#         "AddressLine2": "(And all Portugal Locations)",
#         "City": "Pinheiro",
#         "Country": "PORTUGAL",
#         "PostalCode": "4485-000",
#         "TelephoneOrFax": null
#       },
#       {
#         "EndUser": "DSV AIR & SEA Inc",
#         "AddressLine1": "Driver Road unit 4",
#         "AddressLine2": "(And all Canadian Locations)",
#         "City": "Brampton",
#         "Country": "CANADA",
#         "PostalCode": "L6T 5V2",
#         "TelephoneOrFax": null
#       },
#       {
#         "EndUser": "SERVI LOGISTICA LTDA.",
#         "AddressLine1": "Avenida Moema, 877 – Indianopolis",
#         "AddressLine2": "(And all Brazilian Locations)",
#         "City": "Sao Paulo- SP",
#         "Country": "BRAZIL",
#         "PostalCode": "04077-023",
#         "TelephoneOrFax": null
#       },
#       {
#         "EndUser": "Schenker do Brasil Transportes Internacionais LTDA.",
#         "AddressLine1": "Rua Geraldo Flausino Gomes, 78",
#         "AddressLine2": "(And all Brazilian Locations)",
#         "City": "Sao Paulo- SP",
#         "Country": "BRAZIL",
#         "PostalCode": "04575-093",
#         "TelephoneOrFax": null
#       },
#       {
#         "EndUser": "Transportadora Aquariun LTDA.",
#         "AddressLine1": "Rua Marginal Botucatu – SP",
#         "AddressLine2": "(And all Brazilian Locations)",
#         "City": "Botucatu",
#         "Country": "BRAZIL",
#         "PostalCode": "18606-550",
#         "TelephoneOrFax": null
#       },
#       {
#         "EndUser": "DHL Express (Brazil) LTDA.",
#         "AddressLine1": "Avenida Santa Marina, 1660-Lapa",
#         "AddressLine2": "(And all Brazilian Locations)",
#         "City": "Sao Paulo- SP",
#         "Country": "BRAZIL",
#         "PostalCode": null,
#         "TelephoneOrFax": null
#       },
#       {
#         "EndUser": "SCHENKER S.A.",
#         "AddressLine1": "37 route principale du port CE 214",
#         "AddressLine2": "(And all French Locations)",
#         "City": "Gennevilliers",
#         "Country": "FRANCE",
#         "PostalCode": "F-92 637",
#         "TelephoneOrFax": null
#       },
#       {
#         "EndUser": "DB SCHENKER LOGISTICS KOREA,
#         "AddressLine1": "Airport Logistics Park G3 block, 97-49 Gonghangdong-ro 296 beon-gil, Junggu",
#         "AddressLine2": "(And all South Korean Locations)",
#         "City": "Incheon",
#         "Country": "KOREA, REPUBLIC OF (SOUTH KOREA)",
#         "PostalCode": "22379",
#         "TelephoneOrFax": null
#       },
#       {
#         "EndUser": "DHL Express Sort Centre Paris",
#         "AddressLine1": "Sort centre, 9 Rue du Cdt d Estienne d Orves ZAC du parc des Chanteraines",
#         "AddressLine2": "(And all French Locations)",
#         "City": "Villeneuve La Garenne",
#         "Country": "FRANCE",
#         "PostalCode": null,
#         "TelephoneOrFax": null
#       },
#       {
#         "EndUser": "UPS do Brasil Remessas Expresso LTDA",
#         "AddressLine1": "Rua Dom Aguirre, nº554-Jardim Marajoara",
#         "AddressLine2": "(And all Brazilian Locations)",
#         "City": "Sao Paulo- SP",
#         "Country": "BRAZIL",
#         "PostalCode": "04671245",
#         "TelephoneOrFax": null
#       },
#       {
#         "EndUser": "FEDEX Express Corporation",
#         "AddressLine1": "Avenida das Naçoes Unidas, nº17891-1º andar",
#         "AddressLine2": "(And all Brazilian Locations)",
#         "City": "Sao Paulo- SP",
#         "Country": "BRAZIL",
#         "PostalCode": null,
#         "TelephoneOrFax": null
#       },
#       {
#         "EndUser": "Phenix Transporte de Cargas LTDA.",
#         "AddressLine1": "Avenida Educador Paulo Freire, 111- Parque Novo Mundo",
#         "AddressLine2": "(And all Brazilian Locations)",
#         "City": "Sao Paulo- SP",
#         "Country": "BRAZIL",
#         "PostalCode": "02187-110",
#         "TelephoneOrFax": null
#       },
#       {
#         "EndUser": "Master Freight Transportes Internacionais LTDA.",
#         "AddressLine1": "Alameda dos Jurupis, 452-Conj. 71 - Bloco A- Indianopolis",
#         "AddressLine2": "(And all Brazilian Locations)",
#         "City": "Sao Paulo- SP",
#         "Country": "BRAZIL",
#         "PostalCode": "04088-901",
#         "TelephoneOrFax": null
#       },
#       {
#         "EndUser": "PGL Prime Agenciamento de Carga LTDA.",
#         "AddressLine1": "Av. Dr. Lino de Moraes Leme, 1138-1 Andar-Vila Paulista ",
#         "AddressLine2": "(And all Brazilian Locations)",
#         "City": "Sao Paulo- SP",
#         "Country": "BRAZIL",
#         "PostalCode": "04360-000",
#         "TelephoneOrFax": null
#       },
#       {
#         "EndUser": "M & K Assessoria, Exportadora, Importadora LTDA.",
#         "AddressLine1": " Rua Jacquey, 163-3 ANDAR-Vila Helena ",
#         "AddressLine2": "(And all Brazilian Locations)",
#         "City": "Sao Bernardo do Campo-SP",
#         "Country": "BRAZIL",
#         "PostalCode": "09634-000",
#         "TelephoneOrFax": null
#       },
#       {
#         "EndUser": "Expeditors Internacional do Brasil LTDA.",
#         "AddressLine1": "Av. Jose de Souza Campos, 575 13092-106, Bairro Cambui",
#         "AddressLine2": "(And all Brazilian Locations)",
#         "City": "Campinas",
#         "Country": "BRAZIL",
#         "PostalCode": null,
#         "TelephoneOrFax": null
#       },
#       {
#         "EndUser": "Vila Enterprise",
#         "AddressLine1": "RUA Alvorada, 1289-3º andar",
#         "AddressLine2": "(And all Brazilian Locations)",
#         "City": "Sao Paulo- SP",
#         "Country": "BRAZIL",
#         "PostalCode": "04550-004",
#         "TelephoneOrFax": null
#       },
#       {
#         "EndUser": "KUEHN E + NAGEL S.A.S",
#         "AddressLine1": "Avenida Calle 26, 106-39, Piso 4",
#         "AddressLine2": "(And all Columbian Locations)",
#         "City": "Bogota",
#         "Country": "COLOMBIA",
#         "PostalCode": null,
#         "TelephoneOrFax": null
#       },
#       {
#         "EndUser": "SUNRISE CARGO S.A.",
#         "AddressLine1": "Calle 46 A No 82-54 Porteria 2, Interior 8",
#         "AddressLine2": "(And all Columbian Locations)",
#         "City": "Bogota",
#         "Country": "COLOMBIA",
#         "PostalCode": null,
#         "TelephoneOrFax": null
#       },
#       {
#         "EndUser": "KUEHN E + NAGEL LTDA",
#         "AddressLine1": "Av. Providencia 2331 Of. 301 And 302",
#         "AddressLine2": "(And all Chilean Locations)",
#         "City": "Santiago",
#         "Country": "CHILE",
#         "PostalCode": null,
#         "TelephoneOrFax": null
#       },
#       {
#         "EndUser": "DB SCHENKER LOGISTICS IN CHILE",
#         "AddressLine1": "General del Canto 421, Piso 3",
#         "AddressLine2": "(And all Chilean Locations)",
#         "City": "Santiago",
#         "Country": "CHILE",
#         "PostalCode": "7500588",
#         "TelephoneOrFax": null
#       },
#       {
#         "EndUser": "KUEHN E + NAGEL S.A.",
#         "AddressLine1": "Av. Irlanda E10-16 Y Republica Del Salvador",
#         "AddressLine2": "(And all Ecuador Locations)",
#         "City": "Quito",
#         "Country": "ECUADOR",
#         "PostalCode": null,
#         "TelephoneOrFax": null
#       },
#       {
#         "EndUser": "SERVICIOS AEREOS Y MARITIMOS INTERNACIONALES SA (SAMISA)",
#         "AddressLine1": "Parque Empresarial Colon Edificio Corporativo #2 Piso 2 Oficina # 204",
#         "AddressLine2": "(And all Ecuador Locations)",
#         "City": "Guayaquil",
#         "Country": "ECUADOR",
#         "PostalCode": null,
#         "TelephoneOrFax": null
#       },
#       {
#         "EndUser": "CARIBETRANS, S.A.|BASC CERTIFIED DOMS",
#         "AddressLine1": "Calle Jose Gabriel Garcia No. 8 Apartado Postal DQ00003",
#         "AddressLine2": "(And all Dominican Republic Locations)",
#         "City": "Santo Domingo",
#         "Country": "DOMINICAN REPUBLIC",
#         "PostalCode": "1713",
#         "TelephoneOrFax": null
#       },
#       {
#         "EndUser": "DB SCHENKER ",
#         "AddressLine1": "Av. 27 de Febrero Esq. Tiradentes, Plaza Merengue Local 102",
#         "AddressLine2": "(And all Dominican Republic Locations)",
#         "City": "Santo Domingo",
#         "Country": "DOMINICAN REPUBLIC",
#         "PostalCode": null,
#         "TelephoneOrFax": null
#       }
#     ],
#     "SpecificEndUse": {
#       "EndUse": "5344-00-1 Valve is used as a component of the anti-icing air system. Valve is used to control the flow of engine bleed air within the anti-icing system."
#     },
#     "ExportItemInformation": [
#       {
#         "ExportItem": "Export Item #1",
#         "ECCN": "9A610",
#         "APP": null,
#         "ProductModelNumber": "5344-00-1",
#         "CCATSNumber": null,
#         "Quantity": 1,
#         "Units": "each",
#         "UnitPrice": "$5995",
#         "TotalPrice": "$5995",
#         "Manufacturer": "Aero Fluid Products",
#         "TechnicalDescription": "5344-00-1 Normally closed 1.5” shutoff valve that is solenoid operated. There is also a switch to indicate valve position."
#       },
#       {
#         "ExportItem": "Export Item #2",
#         "ECCN": "9E610",
#         "APP": null,
#         "ProductModelNumber": "Technology",
#         "CCATSNumber": null,
#         "Quantity": 1,
#         "Units": "Lot",
#         "UnitPrice": "$1",
#         "TotalPrice": "$1",
#         "Manufacturer": "Aero Fluid Products",
#         "TechnicalDescription": "The 9E610 Technology to be provided to Embraer is required to support the design, installation, maintenance, and repair of the 5344-00-1. The Information may be in any tangible or intangible form, such as written or oral communications, drawings, photographs, engineering designs and specifications, computer-aided design files, manuals or documentation, electronic media or information revealed through visual inspection."
#       }
#     ],
#     "TotalApplicationDollarValue": "$5,996.00",
#     "AdditionalInformation": {
#       "Information": "The remainder of the Intermediate Consignees are in Block 19."
#     },
#     "DocumentsAttachedToApplication": [
#       {
#         "Title": "Embraer End User Statement",
#         "Author": "Embraer S.A.",
#         "DocumentType": "Import/End-User Certificate",
#         "View": "Copy"
#       },
#       {
#         "Title": "AFP0080",
#         "Author": "Zeljko Tolo",
#         "DocumentType": "Letter of Explanation",
#         "View": "Letter of Explanation"
#       },
#       {
#         "Title": "5344-00-1 Acceptance Test Report",
#         "Author": "Aero Fluid Products",
#         "DocumentType": "Tech. Specs.",
#         "View": null
#       },
#       {
#         "Title": "5344-00-1 Drawing",
#         "Author": "Aero Fluid Products",
#         "DocumentType": "Tech. Specs.",
#         "View": null
#       }
#     ],
#     "SignerInformation": {
#       "Name": "Z.TOLO",
#       "Title": "Dir of Comp",
#       "Email": "ztolo@aerofp.com"
#     }
#   }
# }
# ```
